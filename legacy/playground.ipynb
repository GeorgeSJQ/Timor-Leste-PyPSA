# %%
import pandas as pd
import pypsa
n = pypsa.Network()

# %%
YEAR = 2030
url = f"https://raw.githubusercontent.com/PyPSA/technology-data/master/outputs/costs_{YEAR}.csv"
costs = pd.read_csv(url, index_col=[0, 1])
costs.loc[costs.unit.str.contains("/kW"), "value"] *= 1e3
costs = costs.value.unstack().fillna({"discount rate": 0.07, "lifetime": 20, "FOM": 0})

# %%
costs.to_csv("technology_costs_2030.csv")

# %%
n.import_from_netcdf(r"results\optimized_network.nc")
# Out:
# INFO:gribapi.bindings:ecCodes library not found using name 'eccodes'.
# INFO:gribapi.bindings:ecCodes library not found using name 'libeccodes.so'.
# INFO:gribapi.bindings:ecCodes library not found using name 'libeccodes'.
# c:\Users\Jiuqi Shang\Desktop\Timor Leste\timor-pypsa\.venv\Lib\site-packages\xarray\backends\plugins.py:109: RuntimeWarning:
#
# Engine 'cfgrib' loading failed:
# Could not load the ecCodes library!
#
# INFO:pypsa.network.io:New version 1.0.7 available! (Current: 1.0.6)
# INFO:pypsa.network.io:Imported network 'Timor Leste Grid' has buses, carriers, generators, lines, loads, storage_units, sub_networks

# %%
n.generators
# Out:
#                     bus control type  p_nom  p_nom_mod  p_nom_extendable  \
# name
# Betano_Gen       Betano   Slack       136.0        0.0             False
# Hera_Gen           Hera      PQ       119.0        0.0             False
# Solar_Dili         Dili      PQ         0.0        0.0              True
# Solar_Baucau     Baucau      PQ         0.0        0.0              True
# Wind_Lospalos  Lospalos      PQ         0.0        0.0              True
# Wind_Suai          Suai      PQ         0.0        0.0              True
#
#                p_nom_min  p_nom_max  p_nom_set  p_min_pu  ...  min_up_time  \
# name                                                      ...
# Betano_Gen           0.0        inf        NaN       0.2  ...            0
# Hera_Gen             0.0        inf        NaN       0.2  ...            0
# Solar_Dili           0.0        inf        NaN       0.0  ...            0
# Solar_Baucau         0.0        inf        NaN       0.0  ...            0
# Wind_Lospalos        0.0        inf        NaN       0.0  ...            0
# Wind_Suai            0.0        inf        NaN       0.0  ...            0
#
#                min_down_time  up_time_before  down_time_before  ramp_limit_up  \
# name
# Betano_Gen                 0               1                 0            1.0
# Hera_Gen                   0               1                 0            1.0
# Solar_Dili                 0               1                 0            NaN
# Solar_Baucau               0               1                 0            NaN
# Wind_Lospalos              0               1                 0            NaN
# Wind_Suai                  0               1                 0            NaN
#
#                ramp_limit_down ramp_limit_start_up  ramp_limit_shut_down  \
# name
# Betano_Gen                 1.0                 1.0                   1.0
# Hera_Gen                   1.0                 1.0                   1.0
# Solar_Dili                 NaN                 1.0                   1.0
# Solar_Baucau               NaN                 1.0                   1.0
# Wind_Lospalos              NaN                 1.0                   1.0
# Wind_Suai                  NaN                 1.0                   1.0
#
#                weight  p_nom_opt
# name
# Betano_Gen        1.0      136.0
# Hera_Gen          1.0      119.0
# Solar_Dili        1.0       -0.0
# Solar_Baucau      1.0       -0.0
# Wind_Lospalos     1.0       -0.0
# Wind_Suai         1.0       -0.0
#
# [6 rows x 38 columns]

# %%
n.statistics.opex()
# Out:
# component    carrier
# Generator    Diesel Generator    8.683456e+07
# StorageUnit  Battery Storage     1.828337e+03
# dtype: float64
